# %%
from data.extract_data import ExtractData
from bokeh.io import output_notebook, show
from bokeh.layouts import row, gridplot
from data import data_helper
#from charts import FuelTypePlot, EmissionByMakePlot
from charts.emission_by_fuel import EmissionByFuelPlot

ed = ExtractData()
data = ed.extract()

#fplot = FuelTypePlot(data)
fplot = EmissionByFuelPlot(data)
#charts = []
#for ct in sorted(data_helper.country.keys()):
#    fplot.processByCountry(ct)
#    charts.append(fplot.plot())
#    print(ct)

output_notebook()
#show(row(charts[0], charts[1], charts[2], charts[3], charts[4], charts[5],\
#          charts[6], charts[7], charts[8]))
#show(gridplot(charts, ncols = 2))

fplot.process()
show(fplot.plot())
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2afaeaa7-8509-4ab9-8cbc-9eaaca0fbbb8">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3a6d66cd-1ed6-4575-81c3-cf4199397250"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
# ...

# %%
from data.extract_data import ExtractData
from bokeh.io import output_notebook, show
from bokeh.layouts import row, gridplot
from data import data_helper
#from charts import FuelTypePlot, EmissionByMakePlot
from charts.emission_by_mass import EmissionByMassPlot

ed = ExtractData()
data = ed.extract()

#fplot = FuelTypePlot(data)
mplot = EmissionByMassPlot(data)
#charts = []
#for ct in sorted(data_helper.country.keys()):
#    fplot.processByCountry(ct)
#    charts.append(fplot.plot())
#    print(ct)

output_notebook()
#show(row(charts[0], charts[1], charts[2], charts[3], charts[4], charts[5],\
#          charts[6], charts[7], charts[8]))
#show(gridplot(charts, ncols = 2))

show(mplot.plot())
